# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
# Reading the Data
df = pd.read_csv('C:/Users/chowd/OneDrive/Desktop/Datasets/Housing.csv')

# %%
# Display some rows
df.head()
# Out:
#       price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0  13300000  7420         4          2        3      yes        no       no
# 1  12250000  8960         4          4        4      yes        no       no
# 2  12250000  9960         3          2        2      yes        no      yes
# 3  12215000  7500         4          2        2      yes        no      yes
# 4  11410000  7420         4          1        2      yes       yes      yes
#
#   hotwaterheating airconditioning  parking prefarea furnishingstatus
# 0              no             yes        2      yes        furnished
# 1              no             yes        3       no        furnished
# 2              no              no        2      yes   semi-furnished
# 3              no             yes        3      yes        furnished
# 4              no             yes        2       no        furnished

# %%
df.shape
# Out:
# (545, 13)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 545 entries, 0 to 544
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   price             545 non-null    int64
#  1   area              545 non-null    int64
#  2   bedrooms          545 non-null    int64
#  3   bathrooms         545 non-null    int64
#  4   stories           545 non-null    int64
#  5   mainroad          545 non-null    object
#  6   guestroom         545 non-null    object
#  7   basement          545 non-null    object
#  8   hotwaterheating   545 non-null    object
#  9   airconditioning   545 non-null    object
#  10  parking           545 non-null    int64
#  11  prefarea          545 non-null    object
#  12  furnishingstatus  545 non-null    object
# dtypes: int64(6), object(7)
# memory usage: 55.5+ KB

# %%
# Viewing statistics about the data
df.describe()
# Out:
#               price          area    bedrooms   bathrooms     stories  \
# count  5.450000e+02    545.000000  545.000000  545.000000  545.000000
# mean   4.766729e+06   5150.541284    2.965138    1.286239    1.805505
# std    1.870440e+06   2170.141023    0.738064    0.502470    0.867492
# min    1.750000e+06   1650.000000    1.000000    1.000000    1.000000
# 25%    3.430000e+06   3600.000000    2.000000    1.000000    1.000000
# 50%    4.340000e+06   4600.000000    3.000000    1.000000    2.000000
# 75%    5.740000e+06   6360.000000    3.000000    2.000000    2.000000
# max    1.330000e+07  16200.000000    6.000000    4.000000    4.000000
#
#           parking
# count  545.000000
# mean     0.693578
# std      0.861586
# min      0.000000
# 25%      0.000000
# 50%      0.000000
# 75%      1.000000
# max      3.000000

# %%
# Checking for missing values
pd.DataFrame(df.isnull().sum(), columns = ['Count of missing values'])
# Out:
#                   Count of missing values
# price                                   0
# area                                    0
# bedrooms                                0
# bathrooms                               0
# stories                                 0
# mainroad                                0
# guestroom                               0
# basement                                0
# hotwaterheating                         0
# airconditioning                         0
# parking                                 0
# prefarea                                0
# furnishingstatus                        0

# %%
# Viewing statistics of the categorical columns
df.describe(include = [object])
# Out:
#        mainroad guestroom basement hotwaterheating airconditioning prefarea  \
# count       545       545      545             545             545      545
# unique        2         2        2               2               2        2
# top         yes        no       no              no              no       no
# freq        468       448      354             520             373      417
#
#        furnishingstatus
# count               545
# unique                3
# top      semi-furnished
# freq                227

# %%
# Checking for duplicate values
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [price, area, bedrooms, bathrooms, stories, mainroad, guestroom, basement, hotwaterheating, airconditioning, parking, prefarea, furnishingstatus]
# Index: []

# %%
# Getting the column  names
df.columns
# Out:
# Index(['price', 'area', 'bedrooms', 'bathrooms', 'stories', 'mainroad',
#        'guestroom', 'basement', 'hotwaterheating', 'airconditioning',
#        'parking', 'prefarea', 'furnishingstatus'],
#       dtype='object')

# %%
# Hence we see no duplicate,null or missing values are there.

# %%
# Now we do some EDA

plt.figure (figsize =(20,8))

plt.subplot(1,2,1)
plt.title('House Price Distribution Plot')
sns.distplot(df.price)

plt.subplot(1,2,2)
sns.boxplot(df.price)
plt.title('House Pricing Spread or Boxplot')

plt.show()

# %%
# Visualising categorical data

categorical_list = [x for x in df.columns if df[x].dtype == 'object']

# %%
for x in categorical_list: print(x)
# Out:
# mainroad
# guestroom
# basement
# hotwaterheating
# airconditioning
# prefarea
# furnishingstatus

# %%
plt.figure(figsize = (15,6))

plt.subplot(1,3,1)
plt1 = df['mainroad'].value_counts().plot(kind = 'bar')
plt.title('Mainroad Histogram')
plt1.set(xlabel = 'mainroad', ylabel = 'Frequency of mainroad')

plt.subplot(1,3,2)
plt1 = df['guestroom'].value_counts().plot(kind = 'bar')
plt.title('Guestroom Histogram')
plt1.set(xlabel ='guestroom', ylabel = 'Frequency of guestroom')

plt.subplot(1,3,3)
plt1 = df['basement'].value_counts().plot(kind ='bar')
plt.title('basement Histogram')
plt1.set(xlabel ='basement', ylabel = 'Frequency of basement')

plt.show()

# %%
plt.figure (figsize = (20,8))
plt.subplot(2,2,1)
plt1 = df['hotwaterheating'].value_counts().plot(kind = 'bar', color = 'r')
plt.title('hotwaterheating histogram')
plt1.set(xlabel ='hotwaterheating', ylabel ='Frequency of hotwaterheating')


plt.subplot(2,2,2)
plt1 = df['airconditioning'].value_counts().plot(kind = 'bar', color = 'r')
plt.title('airconditioning histogram')
plt1.set(xlabel = 'airconditioning', ylabel ='Frquency of airconditioning')

plt.subplot(2,2,3)
plt1 = df['prefarea'].value_counts().plot(kind ='bar', color = 'r')
plt.title('prefarea histogram')
plt1.set(xlabel = 'prefarea', ylabel= 'Frequency of prefarea')


plt.subplot(2,2,4)
plt1 = df['furnishingstatus'].value_counts().plot(kind = 'bar', color = 'r')
plt.title('furnishingstatus')
plt1.set(xlabel= 'furnishingstatus', ylabel = 'Frequency of furnishingstatus')

plt.show()

# %%
plt.figure (figsize = (10,5))

plt.subplot(1,2,1)
plt.title('Mainroad vs Price')
sns.boxplot(x = df.mainroad, y = df.price, palette = ('cubehelix'))

plt.subplot(1,2,2)
plt.title('guestroom vs Price')
sns.boxplot(x = df.guestroom, y = df.price, palette = ('PuBuGn'))

plt.show()

# %% [markdown]
# We see that having mainroad and a guestroom have an impact on the price.

# %%
plt.figure(figsize = (10,5))

plt.subplot(1,2,1)
plt.title('basement vs price')
sns.boxplot( x = df.basement, y = df.price, palette = 'cubehelix')

plt.subplot(1,2,2)
plt.title('hotwaterheating vs price')
sns.boxplot(x = df.hotwaterheating, y = df.price, palette = 'PuBuGn')

plt.show()

# %% [markdown]
# Inference : Having a basement and having a hotwater supply have slight correlation with price.

# %%
plt.figure (figsize = (10,5))

plt.subplot(1,3,1)
plt.title('airconditioning vs price')
sns.boxplot(x = df.airconditioning , y = df.price, palette = 'cubehelix')

plt.subplot(1,3,2)
plt.title('prefarea vs price')
sns.boxplot( x= df.prefarea, y = df.price, palette = 'PuBuGn')

plt.subplot(1,3,3)
plt.title('furnishingstatus vs price')
sns.boxplot(x = df.furnishingstatus, y = df.price, palette = 'PuBuGn')
plt.xticks(rotation = 45)

plt.show()

# %% [markdown]
# Inference : Having aircondition and prefarea have positive correlation with Price of the house. Also a furnished house would have higher price.

# %%
# Visualizing numerical data
numerical_list = [x for x in df.columns if df[x].dtype in ('int64','float64')]
print(numerical_list)
# Out:
# ['price', 'area', 'bedrooms', 'bathrooms', 'stories', 'parking']

# %%
def scatter(x, fig):
    plt.subplot(5,2, fig)
    plt.scatter(df[x], df['price'])
    plt.title(x +  ' vs price')
    plt.ylabel('Price')
    plt.xlabel(x)
    
plt.figure(figsize = (10,20))

scatter('area',1)
scatter('bedrooms',2)
scatter('bathrooms',3)
scatter('stories',4)
scatter('parking',5)

plt.tight_layout()

# %% [markdown]
# Inference: Area has a strong positive correlation with price.

# %%
sns.pairplot(df)
plt.show()

# %%
cor_matrix = df[numerical_list].corr()
plt.figure(figsize = (12,8))
sns.heatmap(cor_matrix, annot = True, cmap = 'coolwarm', linewidths = 0.5)
plt.title('Correlation Heatmap')
plt.show()

# %%
df.head()
# Out:
#       price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0  13300000  7420         4          2        3      yes        no       no
# 1  12250000  8960         4          4        4      yes        no       no
# 2  12250000  9960         3          2        2      yes        no      yes
# 3  12215000  7500         4          2        2      yes        no      yes
# 4  11410000  7420         4          1        2      yes       yes      yes
#
#   hotwaterheating airconditioning  parking prefarea furnishingstatus
# 0              no             yes        2      yes        furnished
# 1              no             yes        3       no        furnished
# 2              no              no        2      yes   semi-furnished
# 3              no             yes        3      yes        furnished
# 4              no             yes        2       no        furnished

# %%
# Defining the map function
def dummies(x,df):
    temp = pd.get_dummies(df[x], drop_first = True).astype(int)
    df = pd.concat([df, temp], axis = 1)
    df.drop([x], axis = 1, inplace = True)
    return df
# Applying the function to the df

df = dummies('mainroad',df)
df = dummies('guestroom',df)
df = dummies('hotwaterheating',df)
df = dummies('basement',df)
df = dummies('airconditioning',df)
df = dummies('prefarea',df)
df = dummies('furnishingstatus',df)

# %%
df.tail()
# Out:
#        price  area  bedrooms  bathrooms  stories  parking  yes  yes  yes  yes  \
# 540  1820000  3000         2          1        1        2    1    0    0    1
# 541  1767150  2400         3          1        1        0    0    0    0    0
# 542  1750000  3620         2          1        1        0    1    0    0    0
# 543  1750000  2910         3          1        1        0    0    0    0    0
# 544  1750000  3850         3          1        2        0    1    0    0    0
#
#      yes  yes  semi-furnished  unfurnished
# 540    0    0               0            1
# 541    0    0               1            0
# 542    0    0               0            1
# 543    0    0               0            0
# 544    0    0               0            1

# %%
df.shape
# Out:
# (545, 14)

# %%
from sklearn.model_selection import train_test_split

np.random.seed(0)
X_train,X_test,y_train,y_test = train_test_split(df.drop('price',axis =1),df['price'],test_size = 0.2,random_state =42)

# %%
from sklearn.preprocessing import LabelEncoder , StandardScaler
sc = StandardScaler(with_std = True)
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %%
# RFE
from sklearn.feature_selection import RFE
from sklearn.linear_model import LinearRegression
import statsmodels.api as sm
from statsmodels.stats.outliers_influence import variance_inflation_factor

# %%
# Linear Regression Model

lr_model = LinearRegression()
lr_model.fit(X_train, y_train)
y_pred = lr_model.predict(X_test)

# %%
print(f"Training Score: {lr_model.score(X_train, y_train)}") 
print(f"Testing Score: {lr_model.score(X_test, y_test)}")
# Out:
# Training Score: 0.6859438988560158
# Testing Score: 0.6529242642153175

# %%
from sklearn.metrics import mean_absolute_error,mean_squared_error , r2_score
from sklearn.model_selection import  train_test_split
from sklearn.ensemble import RandomForestRegressor
mae = mean_absolute_error(y_test, y_pred)
mse = mean_squared_error(y_test, y_pred)
print(f"\nMAE: {mae}")
print(f"MSE: {mse}")
# Out:
# MAE: 970043.4039201643
# MSE: 1754318687330.6685

# %%
r2 = r2_score(y_test, y_pred)
print(f"Final Acc For Linear Regression Model: {r2}")
# Out:
# Final Acc For Linear Regression Model: 0.6529242642153175

# %%
# Random forest model
rf_model = RandomForestRegressor()
rf_model.fit(X_train, y_train)
y_pred_rf = rf_model.predict(X_test)

# %%
print(f"Training Score: {rf_model.score(X_train, y_train)}") 
print(f"Testing Score: {rf_model.score(X_test, y_test)}")
# Out:
# Training Score: 0.9464825097853644
# Testing Score: 0.6248858881993359

# %%
mae = mean_absolute_error(y_test, y_pred_rf)
mse = mean_squared_error(y_test, y_pred_rf)
print(f"\nMAE: {mae}")
print(f"MSE: {mse}")
# Out:
# MAE: 1010217.3837920488
# MSE: 1896040628497.2954

# %%
r2 = r2_score(y_test, y_pred_rf)
print(f"Final Acc For Random Forest Model: {r2}")
# Out:
# Final Acc For Random Forest Model: 0.6248858881993359
